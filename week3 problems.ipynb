# %%
# program 1 - Print even no using continue statement

for i in range(0,10):
  if i % 2 != 0:
    continue
  print('i=',i)

# program 2 - Check prime no or not

n = int(input('enter the number:'))
for i in range(2,n):
  if n % i == 0:
    print('the number ',n,' is not prime')
    break
else:
  print('the number',n,' is a prime')

# program 3 - fibonacci sequence

n = int(input('enter no of numbers in series'))
a = 0
b = 1
sum = 0
count = 1
print("fibonacci:",end ="")
while(count<=n):
  print(sum,end="")
  count +=1
  a = b
  b = sum
  sum = a+b

# program 4 - series of four

n = int(input('enter no of terms'))
str1 = str(4)
for i in range(0,n):
  print('str1:',str1)
  str1 = str1 + str(4)

# program 5 - seven multiplication tables

n = 7
for i in range (1,100):
   print(n, 'x', i, '=', n*i)
   if i == 11:
    break
print('Values out of loop')

# program 6 - Count nos with digit 3

count = 0
for i in range(1,10000):
  if "3" in str(i):
    count += 1
print("Numbers between 1 & 10,000 that contain the digit 3:", count)

# program 7 - find string index

s = str(input('enter a string'))
x = input('enter letter to be found')
y = s.index(x)

while True:
  try:
   print("the index of letter:",s.index(x))
   break
  except:
     print('error')

# Program 8 - Sum of first 10 nos
n = int(input('enter last number'))
sum = 0
for i in range(1,n+1):
  sum = i + sum
print("\nSum =", sum)

# Program 9 - Factorial calculator

n = int(input('enter last number'))
Factorial = 1
for i in range(1,n+1):
  Factorial = i*Factorial
print("nfactorial =", Factorial)


# program 11 - continue and break examples

# Continue statement is used to skip the articular iteration in the loop,
# break statement is used to terminate the entire loop.

for i in range(1,10):
  if i ==7:
    continue
print('i:',i)

for i in range(1,10):
  if i ==7:
    break
print('i:',i)


# program 12 -Compound interest calculation need to change to variable rate

principal = int(input('enter principal no'))
rate = int(input('enter rate'))
time =int(input('enter time'))

Amount = principal * (pow((1 + rate / 100), time))
CI = Amount - principal
print("Compound interest is", CI)

# program 13 - rock, paper, scissor game

# dfine computer input random
# dfine usser input radom
# logic for which wins
# count used for 5 rounds

import random

while True:
    user_action = input("Enter a choice (rock, paper, scissors): ")
    possible_actions = ["rock", "paper", "scissors"]
    computer_action = random.choice(possible_actions)
    print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

    if user_action == computer_action:
        print(f"Both players selected {user_action}. It's a tie!")
    elif user_action == "rock":
        if computer_action == "scissors":
            print("Rock smashes scissors! You win!")
        else:
            print("Paper covers rock! You lose.")
    elif user_action == "paper":
        if computer_action == "rock":
            print("Paper covers rock! You win!")
        else:
            print("Scissors cuts paper! You lose.")
    elif user_action == "scissors":
        if computer_action == "paper":
            print("Scissors cuts paper! You win!")
        else:
            print("Rock smashes scissors! You lose.")

# program 14 - Sum of series

N = int(input('enter no of terms'))
fact = 1
sum = 1

for i in range(1,N+1):
  fact = fact * i
  sum = fact + sum
print("sumofnos =",sum)
print("nfactorial=",fact)


# program 15 - nested loop example
# Nested loop - it is basically a loop inside which one/multiple more loops are run
# to iterate multiple variables/ conditionals at the same time to solve the program.

for i in range(2, 4):

    # Printing inside the outer loop
    # Running inner loop from 1 to 10
    for j in range(1, 11):

        # Printing inside the inner loop
        print(i, "*", j, "=", i*j)
    # Printing inside the outer loop
    print()
